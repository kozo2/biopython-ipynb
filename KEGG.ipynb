# %% [markdown]
# [KEGG](http://www.kegg.jp/) is a database resource for understanding high-level functions and utilities of the biological system, such as the cell, the organism and the ecosystem, from molecular-level information, especially large-scale molecular datasets generated by genome sequencing and other high-throughput experimental technologies.
#
# Please note that the KEGG parser implementation in Biopython is incomplete.
# While the KEGG website indicates many flat file formats, only parsers and writers for compound, enzyme, and map are currently implemented.
# However, a generic parser is implemented to handle the other formats.

# %% [markdown]
# # Parsing KEGG records
# Parsing a KEGG record is as simple as using any other file format parser in Biopython.

# %%
from Bio.KEGG import Enzyme

# %%
import requests
from StringIO import StringIO

# %%
records = Enzyme.parse(StringIO(requests.get('http://rest.kegg.jp/get/ec:5.4.2.2').content))

# %%
record = list(records)[0]

# %%
record.classname
# Out:
# ['Isomerases;',
#  'Intramolecular transferases;',
#  'Phosphotransferases (phosphomutases)']

# %%
record.entry
# Out:
# '5.4.2.2'
